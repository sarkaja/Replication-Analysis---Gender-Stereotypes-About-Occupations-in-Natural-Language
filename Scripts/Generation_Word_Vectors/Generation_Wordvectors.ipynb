# %%
#Here is the example how to use fasttext skipgram, unfortunately there are only 11 corpora
#last one - Disney corpus is missing due to the fact that it is not even present on the creators' website
#after running the code two files are created for each corpus - model and vectors

# %%
import fasttext
"utf-8"
model_gutenberg = fasttext.skipgram('gutenberg_corpus.txt', 'model_gutenberg')
print (model_gutenberg.words)
# Out:
# {'hop', 'quemma', 'onehalf', 'bonnetstrings', 'naturvorgänge', 'letizia', '1009', 'jésus', 'warcries', 'campaign', 'mixer', 'riunite', 'comana', 'descubriendo', 'apeldoorn', 'breeze', 'erratic', 'disproof', 'geschick', 'verschijnselen', 'husting', 'machiavelli', 'sensationalistic', 'incorporate', 'ristiä', 'rospigliosi', 'ffiz', 'hali', 'begegnen', 'lochaber', 'skam', 'sung', 'inter', 'displayed', 'branded', 'censure', 'gedreven', 'pêcheries', 'obispos', 'excruciating', 'schaars', 'matkani', 'abogados', 'rudolstadt', 'friendhe', 'sphagnum', 'sovra', 'sauvansa', 'shorthandled', 'meeres', 'ilmalaivat', 'débarque', 'denotes', 'hartioilleen', 'kirchlichen', 'supporter', 'difference', 'jesuit', 'sv', 'patton', 'sorru', 'winecup', 'haji', 'sadness', 'abduct', 'landengte', 'fosos', 'discus', 'built', 'turpin', 'veracidade', 'plasticity', 'gejaagd', '1328', 'celimene', 'erklaert', 'croyland', 'divorzio', 'ventriloquist', 'demanded', 'ornatus', 'daags', 'oka', 'nabal', 'ausdehnen', 'expéditio
# ...

# %%
import fasttext
"utf-8"
model_childrens_TV_combined = fasttext.skipgram('childrens_TV_combined_corpus.txt', 'model_childrens_TV_combined')
print (model_childrens_TV_combined.words)
# Out:
# {'hop', 'partying', 'wronglynn', 'goon', 'surfer', 'pummeled', 'campaign', 'mixer', 'lintboy', 'giggleslincoln', 'breeze', 'cheekbone', 'fatherson', 'engraving', 'doof', 'screaming', 'arrrgh', 'behalf', 'crossbones', 'littering', 'sung', 'sawing', 'remove', 'colspan5', 'displayed', 'garageedit', 'crumpled', 'excruciating', 'holdup', 'abogados', "we\\'92ve", 'troublesome', 'criminal', 'cando', 'cheers', 'downlynn', 'waft', 'pirates', 'flashbacklynn', 'gellatin', "t\\'edtio", 'rid', 'supporter', 'sway', 'difference', 'patton', 'ravine', 'athe', 'sadness', 'abduct', 'discus', 'built', 'arrrr', 'herbert', 'ventriloquist', 'voyager', 'interesting', 'protect', 'unprofessional', 'elongated', 'nonplussed', 'bagel', 'mebane', 'teeming', 'substance', 'quanita', 'spectre', 'freestyle', 'yammering', 'general', 'trough', 'slowpoke', 'kissy', 'sweatband', 'grouped', 'toads', 'br', '84b', 'dossier', 'rangers', 'happiest', 'nagging', 'portland', 'sister', 'barge', "av\\'f4", 'hooo', 'emitting', 'ins
# ...

# %%
import fasttext
"utf-8"
model_adult_speech = fasttext.skipgram('lemmatized_adult_speech_corpus.txt', 'model_adult_speech')
print (model_adult_speech.words)
# Out:
# {'hop', 'partying', 'ford', 'raped', 'proper', 'gathered', 'effort', 'par', 'packaged', 'word', 'inspired', 'laser', 'drying', 'lab', 'summer', 'shape', 'campaign', 'zone', 'mixer', 'breeze', 'birth', "what'll", 'waking', 'bind', 'screaming', 'allowance', 'michigan', 'incorporate', 'vacant', 'hungry', 'firewood', 'fuss', 'fighting', 'cathedral', 'sung', 'remove', 'athletic', 'subtle', 'attempt', 'shocked', 'daddy', 'marcos', 'pseudo', 'criminal', 'financially', 'clearly', 'assumption', 'vent', 'pump', 'aggressive', 'guatemala', 'rid', 'so-called', 'renting', 'supporter', 'sway', 'difference', 'beyond', 'attorney', 'springtime', 'bronx', 'october', 'restroom', 'tenant', 'challenged', 'discus', 'built', 'afterwards', 'hint', 'adaptation', 'lax', 'tub', 'room', 'truly', 'miracle', 'demanded', 'voyager', 'funnel', 'mop', 'entrance', 'interesting', 'phoenix', 'bernardino', 'conversion', 'protect', 'borrowing', 'smelling', 'zillion', 'bagel', 'surround', 'substance', 'sweetie', 'improvemen
# ...

# %%
import fasttext
"utf-8"
model_childes_both = fasttext.skipgram('lemmatized_corpus_both.txt', 'model_childes_both')
print (model_childes_both.words)
# Out:
# {'hop', 'nightnight', 'ford', 'gathered', 'proper', 'effort', 'par', "movie's", 'rawr', 'word', 'drying', 'laser', 'surfer', 'hikin', 'carlton', 'ss', 'lab', 'summer', 'shape', 'meowing', 'mixer', 'zone', 'probe', 'lorna', 'breeze', 'birth', "what'll", 'waking', 'felled', 'polly', 'lickin', 'jenessa', 'doof', 'woooo', 'iceberg', 'screaming', 'jammies', 'allowance', 'michigan', 'hungry', 'cliffor', 'firewood', 'fuss', 'fighting', 'roared', 'gervils', 'timothy', 'bob_coal', 'sung', 'helper', 'smacking', 'sawing', 'remove', 'subtle', 'shocked', 'whistling', 'crumpled', 'daddy', 'damp', 'zig_zag', 'goed', 'troublesome', 'auhh', 'cotuit', 'carby', 'grinch', 'lally', 'clearly', 'eeran', 'assumption', 'squealed', 'vent', 'hunm', 'pump', 'guatemala', 'aggressive', 'rid', 'ge', 'micky', 'tom_thumb', 'perm', 'gyere', 'roadgrader', 'nutcracker', 'yee', 'trusty', 'baum', 'difference', 'beyond', 'springtime', 'bronx', 'october', 'esther', 'malibu', 'sadness', 'discus', 'built', 'afterwards', 'hin
# ...

# %%
import fasttext
"utf-8"
model_childes_children = fasttext.skipgram('lemmatized_corpus_children.txt', 'model_childes_children')
print (model_childes_children.words)
# Out:
# {'hop', 'ford', 'gathered', 'par', 'rawr', 'word', 'drying', 'laser', 'surfer', 'carlton', 'ss', 'lab', 'summer', 'shape', 'meowing', 'mixer', 'probe', 'yeahmommy', 'lorna', 'birth', "what'll", 'waking', 'felled', 'polly', 'woooo', 'screaming', 'jammies', 'allowance', 'michigan', 'hungry', 'firewood', 'fuss', 'fighting', 'roared', 'timothy', 'sung', 'helper', 'sawing', 'shocked', 'whistling', 'daddy', 'damp', 'zig_zag', 'goed', 'troublesome', 'auhh', 'lally', 'hunm', 'pump', 'guatemala', 'rid', 'ge', 'tom_thumb', 'micky', 'roadgrader', 'nutcracker', 'yee', 'baum', 'difference', 'beyond', 'october', 'esther', 'malibu', 'built', 'afterwards', 'hint', 'tub', 'room', 'gleason', 'itty', 'funnel', 'mop', 'oka', 'pff', 'pompom', 'kate', 'debbi', 'interesting', 'phoenix', 'protect', 'noont', 'borrowing', 'smelling', 'growl', 'bagel', "mouse's", 'wite', 'sweetie', 'tart', 'cuss', 'pleakley', 'general', 'trough', 'operating', 'matzo', 'polar', 'brumm', 'nosed', 'd', 'kissy', 'br', 'handsome', 
# ...

# %%
import fasttext
"utf-8"
model_childes_parents = fasttext.skipgram('lemmatized_corpus_parents.txt', 'model_childes_parents')
print (model_childes_parents.words)
# Out:
# {'hop', 'ford', 'gathered', 'proper', 'effort', "movie's", 'par', 'rawr', 'word', 'drying', 'surfer', 'laser', 'ss', 'lab', 'summer', 'shape', 'meowing', 'mixer', 'zone', 'breeze', 'birth', "what'll", 'waking', 'polly', 'lickin', 'jenessa', 'doof', 'iceberg', 'screaming', 'jammies', 'allowance', 'michigan', 'hungry', 'fuss', 'fighting', 'roared', 'timothy', 'sung', 'helper', 'smacking', 'sawing', 'remove', 'subtle', 'shocked', 'whistling', 'crumpled', 'daddy', 'damp', 'zig_zag', 'troublesome', 'cotuit', 'grinch', 'lally', 'clearly', 'eeran', 'assumption', 'squealed', 'vent', 'hunm', 'pump', 'guatemala', 'aggressive', 'rid', 'ge', 'micky', 'gyere', 'roadgrader', 'nutcracker', 'trusty', 'baum', 'difference', 'beyond', 'springtime', 'bronx', 'october', 'esther', 'sadness', 'discus', 'built', 'afterwards', 'hint', 'cardamom', 'tub', 'herbert', 'room', 'truly', 'itty', 'miracle', "brisco's", 'rescuing', 'funnel', 'urgent', "joshua's", 'mop', 'oka', 'pff', 'pompom', "fixit's", 'dink', 'kat
# ...

# %%
import fasttext
"utf-8"
model_child_books = fasttext.skipgram('lemmatized_child_books.txt', 'model_child_books')
print (model_child_books.words)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-7-ef96ea721f59> in <module>
#       1 import fasttext
#       2 "utf-8"
# ----> 3 model_child_books = fasttext.skipgram('lemmatized_child_books.txt', 'model_child_books')
#       4 print (model_child_books.words)
#
# fasttext\fasttext.pyx in fasttext.fasttext.skipgram()
#
# fasttext\fasttext.pyx in fasttext.fasttext.train_wrapper()
#
# fasttext\fasttext.pyx in fasttext.fasttext.load_model()
#
# fasttext\fasttext.pyx in fasttext.fasttext.FastTextModelWrapper.dict_get_word()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xe3 in position 0: unexpected end of data

# %%
import fasttext
"utf-8"
model_nick = fasttext.skipgram('nick_corpus.txt', 'model_nick')
print (model_nick.words)
# Out:
# {'hop', 'partying', 'wronglynn', 'goon', 'surfer', 'pummeled', 'campaign', 'mixer', 'lintboy', 'giggleslincoln', 'breeze', 'cheekbone', 'fatherson', 'engraving', 'screaming', 'arrrgh', 'behalf', 'littering', 'sung', 'sawing', 'remove', 'colspan5', 'displayed', 'crumpled', 'excruciating', 'holdup', 'abogados', 'troublesome', 'criminal', 'cando', 'cheers', 'downlynn', 'waft', 'pirates', 'flashbacklynn', 'gellatin', 'rid', 'supporter', 'sway', 'difference', 'ravine', 'sadness', 'abduct', 'discus', 'built', 'arrrr', 'herbert', 'ventriloquist', 'interesting', 'protect', 'unprofessional', 'elongated', 'nonplussed', 'bagel', 'teeming', 'substance', 'spectre', 'freestyle', 'general', 'trough', 'slowpoke', 'kissy', 'sweatband', 'grouped', 'br', 'rangers', 'happiest', 'nagging', 'portland', 'sister', 'barge', 'hooo', 'emitting', 'instructor', 'baxter', 'rotate', 'imitation', 'attaboy', 'fatter', 'pomp', 'calliope', 'stubbed', 'mcnulty', 'piece', 'krab', 'varsity', 'urine', 'totes', 'dannys', '
# ...

# %%
import fasttext
"utf-8"
model_pbs_adults = fasttext.skipgram('pbs_adults_corpus.txt', 'model_pbs_adults')
print (model_pbs_adults.words)
# Out:
# {'hop', 'thoracic', 'surfer', 'mesoamerican', 'pummeled', 'baskin', 'gillian', 'campaign', 'sutters', 'mixer', 'andrewes', 'breeze', 'cheekbone', 'engraving', 'erratic', 'screaming', 'splayed', 'incorporate', 'penningrowsell', 'behalf', 'judah', 'remove', 'sawing', 'displayed', 'besso', 'branded', 'crumpled', 'excruciating', 'uk', 'troublesome', 'criminal', 'financially', 'cheers', 'pirates', 'ell', 'guatemala', 'analogous', 'rid', 'supporter', 'sway', 'difference', 'jesuit', 'ravine', 'haji', 'esther', 'themis', 'abidi', 'sadness', 'vying', 'discus', 'built', 'turpin', 'holloway', 'scandinavia', 'herbert', 'demanded', 'schele', 'voyager', 'mikimotos', 'interesting', 'protect', 'moreover', 'elongated', 'teeming', 'photographed', 'substance', 'celts', 'general', 'swaab', 'scoured', 'venetian', 'voluntary', 'costanza', '19001929', 'parcel', 'happiest', 'nagging', 'portland', 'huppert', 'sister', 'barge', 'paleontologist', 'emitting', 'instructor', 'newtonian', 'baxter', 'rotate', 'disa
# ...

# %%
import fasttext
"utf-8"
model_pbs_kids = fasttext.skipgram('pbs_kids_corpus.txt', 'model_pbs_kids')
print (model_pbs_kids.words)
# Out:
# {'hop', 'gathered', 'people’s', 'proper', 'effort', 'word', 'laser', 'lab', 'summer', 'shape', 'campaign', 'catapult', 'meowing', 'zone', 'birth', 'waking', 'you’re', 'bind', 'screaming', 'allowance', 'hungry', 'flabbergasted', 'fighting', 'roared', 'helper', 'remove', 'colspan5', 'attempt', 'shocked', 'whistling', 'year’s', 'daddy', 'criminal', 'cheers', 'pirates', 'clearly', '2018', 'rid', 'trusty', 'difference', 'attorney', 'beyond', 'springtime', 'october', 'ravine', 'discus', 'built', 'afterwards', 'hint', 'tub', 'room', 'truly', 'miracle', '1995edit', '000000', 'funnel', 'mop', 'kate', 'entrance', 'interesting', 'protect', 'ramble', 'elongated', 'growl', 'bagel', 'heroes', 'surround', 'mebane', 'frantically', 'quanita', 'sweetie', 'tart', 'secunda', 'general', 'theory', 'struggling', 'd', 'masquerade', 'toads', 'handsome', 'wings', '1995', 'ferb', 'neat', 'rangers', 'clyde', 'killed', 'blingbling', 'memorized', 'prefer', 'wiping', 'sister', 'barge', 'dodgeball', 'stylepadding10
# ...

# %%
import fasttext
"utf-8"
model_simply_scripts = fasttext.skipgram('simply_scripts_corpus.txt', 'model_simply_scripts')
print (model_simply_scripts.words)
# Out:
# {'hop', 'partying', 'ford', 'gathered', 'morez', 'proper', 'effort', 'raped', 'thoracic', 'word', 'drying', 'laser', 'surfer', 'inspired', 'carlton', 'garrowmr', 'scroll', 'paramedics', 'goon', 'buzanis', 'gillian', 'bladed', 'lab', 'summer', 'shape', 'campaign', 'deani', 'rune', 'zone', 'probe', 'f95f', 'alanwhat', 'thatod', 'unshaven', 'communal', 'breeze', 'meth', 'emmayou', 'weod', 'sarahim', 'birth', 'paulai', 'charlieit', 'waking', 'erratic', 'bretti', 'bind', 'voyt', 'citation', 'screaming', 'splayed', 'youshould', 'michigan', 'allowance', 'vacant', 'hungry', 'clemmons', 'behalf', 'fuss', 'fighting', 'mpos', 'cordoned', 'cathedral', 'concourse', 'sung', 'stepladders', 'bumps', 'sawing', 'remove', 'athletic', 'inter', 'subtle', 'sonja', 'displayed', 'davincithe', 'attempt', 'shocked', 'whistling', 'crumpled', 'vhs', 'excruciating', 'stalks', 'daddy', 'damp', 'uk', 'marcos', 'criminal', 'cheers', 'havemeyer', 'waft', 'clearly', 'chloeno', 'vent', 'pump', 'aggressive', 'maidstone
# ...
